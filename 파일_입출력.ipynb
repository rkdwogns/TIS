# %% [markdown]
# <a href="https://colab.research.google.com/github/rkdwogns/TIS/blob/main/%ED%8C%8C%EC%9D%BC_%EC%9E%85%EC%B6%9C%EB%A0%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile sample1.csv
#
# c1, c2, c3
# 1, 1.11, one
# 2, 2.22, two
# 3, 3.33, three
# Out:
# Writing sample1.csv

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
import pandas as pd
pd.read_csv('sample1.csv')
# Out:
#    c1    c2      c3
# 0   1  1.11     one
# 1   2  2.22     two
# 2   3  3.33   three

# %%
# %%writefile sample2.csv
#
# 1, 1.11, one
# 2, 2.22, two
# 3, 3.33, three
# Out:
# Overwriting sample2.csv

# %%
pd.read_csv('sample2.csv', names=['c1', 'c2', 'c3'])
# Out:
#    c1    c2      c3
# 0   1  1.11     one
# 1   2  2.22     two
# 2   3  3.33   three

# %%
# %%writefile sample3.txt
# c1|c2|c3|c4
# 0.179181|-1.538472|1.347553|0.43381
# 1.024209|0.087307|-1.281997|0.49265
# 0.417899|-2.002308|0.255245|-1.10515
# Out:
# Writing sample3.txt

# %%
pd.read_table('sample3.txt', sep='|')
# Out:
#          c1        c2        c3       c4
# 0  0.179181 -1.538472  1.347553  0.43381
# 1  1.024209  0.087307 -1.281997  0.49265
# 2  0.417899 -2.002308  0.255245 -1.10515

# %%
# %%writefile sample4.txt
# 파일 제목: sample4.txt
# 데이터 포맷의 설명:
# c1, c2, c3
# 1, 1.11, one
# 2, 2.22, two
# 3, 3.33, three
# Out:
# Writing sample4.txt

# %%
pd.read_table('sample4.txt', skiprows=[0,1])
# Out:
#        c1, c2, c3
# 0    1, 1.11, one
# 1    2, 2.22, two
# 2  3, 3.33, three

# %%
# %%writefile sample5.csv
# c1, c2, c3
# 1, 1.11, one
# 2, , two
# 누락, 3.33, three
# Out:
# Writing sample5.csv

# %%
df = pd.read_csv('sample5.csv', na_values=['누락', ' '])
df
# Out:
#     c1    c2      c3
# 0  1.0  1.11     one
# 1  2.0   NaN     two
# 2  NaN  3.33   three

# %%
df.to_csv('cleaned_data.csv')

# %%
# !cat cleaned_data.csv
# Out:
# ,c1, c2, c3
# 0,1.0,1.11, one
# 1,2.0,, two
# 2,,3.33, three

# %%
! ls -al
# Out:
# total 40
# drwxr-xr-x 1 root root 4096 Feb 16 04:37 .
# drwxr-xr-x 1 root root 4096 Feb 16 04:12 ..
# -rw-r--r-- 1 root root   55 Feb 16 04:37 cleaned_data.csv
# drwxr-xr-x 4 root root 4096 Feb 14 14:36 .config
# -rw-r--r-- 1 root root   53 Feb 16 04:12 sample1.csv
# -rw-r--r-- 1 root root   42 Feb 16 04:23 sample2.csv
# -rw-r--r-- 1 root root  121 Feb 16 04:28 sample3.txt
# -rw-r--r-- 1 root root  107 Feb 16 04:32 sample4.txt
# -rw-r--r-- 1 root root   53 Feb 16 04:33 sample5.csv
# drwxr-xr-x 1 root root 4096 Feb 14 14:37 sample_data

# %%
! pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df.index = ['a', 'b', 'c']
df
# Out:
#     c1    c2      c3
# a  1.0  1.11     one
# b  2.0   NaN     two
# c  NaN  3.33   three

# %%
df.to_csv('sample9.csv', index=False, header=False)

# %%
# !cat sample9.csv
# Out:
# 1.0,1.11, one
# 2.0,, two
# ,3.33, three

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datascienceschool/docker_rpython/master/data/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
csv_url = "https://raw.githubusercontent.com/IkyeonJo/nepes_lectures/main/M4B(%EC%A4%91%EA%B8%89)/data/trade.csv"
df = pd.read_csv(csv_url)
df
# Out:
#             기간 국가명      수출건수        수출금액       수입건수       수입금액       무역수지  \
# 0    2015년 01월  중국  116932.0  12083947.0   334522.0  8143271.0  3940676.0
# 1    2015년 01월  미국   65888.0   5561545.0   509564.0  3625062.0  1936484.0
# 2    2015년 01월  일본   54017.0   2251307.0    82480.0  3827247.0 -1575940.0
# 3    2015년 02월  중국   86228.0   9927642.0   209100.0  6980874.0  2946768.0
# 4    2015년 02월  미국   60225.0   5021264.0   428678.0  2998216.0  2023048.0
# ..         ...  ..       ...         ...        ...        ...        ...
# 194  2020년 05월  미국  126598.0   4600726.0  1157163.0  4286873.0   313853.0
# 195  2020년 05월  일본  166568.0   1798128.0   133763.0  3102734.0 -1304606.0
# 196  2020년 06월  중국       NaN         NaN        NaN        NaN        NaN
# 197  2020년 06월  미국       NaN         NaN        NaN        NaN        NaN
# 198  2020년 06월  일본       NaN         NaN        NaN        NaN        NaN
#
#      기타사항
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ...

# %%
df.head()
# Out:
#           기간 국가명      수출건수        수출금액      수입건수       수입금액       무역수지  기타사항
# 0  2015년 01월  중국  116932.0  12083947.0  334522.0  8143271.0  3940676.0   NaN
# 1  2015년 01월  미국   65888.0   5561545.0  509564.0  3625062.0  1936484.0   NaN
# 2  2015년 01월  일본   54017.0   2251307.0   82480.0  3827247.0 -1575940.0   NaN
# 3  2015년 02월  중국   86228.0   9927642.0  209100.0  6980874.0  2946768.0   NaN
# 4  2015년 02월  미국   60225.0   5021264.0  428678.0  2998216.0  2023048.0   NaN

# %%
df.tail(10)
# Out:
#             기간 국가명      수출건수        수출금액       수입건수       수입금액       무역수지  \
# 189  2020년 03월  일본  150602.0   2486175.0   153670.0  4394441.0 -1908266.0
# 190  2020년 04월  중국  194716.0  10164071.0   365746.0  9619835.0   544236.0
# 191  2020년 04월  미국  105360.0         NaN  1141118.0  5038739.0        NaN
# 192  2020년 04월  일본  134118.0   1989323.0   141207.0  3989562.0 -2000239.0
# 193  2020년 05월  중국  185320.0  10746069.0   349007.0  8989920.0  1756149.0
# 194  2020년 05월  미국  126598.0   4600726.0  1157163.0  4286873.0   313853.0
# 195  2020년 05월  일본  166568.0   1798128.0   133763.0  3102734.0 -1304606.0
# 196  2020년 06월  중국       NaN         NaN        NaN        NaN        NaN
# 197  2020년 06월  미국       NaN         NaN        NaN        NaN        NaN
# 198  2020년 06월  일본       NaN         NaN        NaN        NaN        NaN
#
#      기타사항
# 189   NaN
# 190   NaN
# 191   NaN
# 192   NaN
# 193   NaN
# 194   NaN
# 195   NaN
# 196   NaN
# 197   NaN
# 198   NaN

# %%
# 연습문제: 인천 서구 아파트 실거래가 데이터 읽어오기
import pandas as pd
path = '/content/drive/MyDrive/Colab Notebooks/인천광역시 서구_공동주택 실거래가_20220531.csv'
df = pd.read_csv(path, encoding='euc-kr')
# df[:,[df['행정구역']=='백석동']]
df
# Out:
#     행정구역                  단지명  합계동호수(건)  합계면적(제곱미터)  합계금액(백만원)  산출기간  \
# 0    백석동  검암역 로열파크씨티 푸르지오 1단지       3.0      218.78     1654.0  최근1년
# 1    백석동  검암역 로열파크씨티 푸르지오 2단지       4.0      331.87     2461.0  최근1년
# 2    백석동                   기타       2.0      116.49        0.0  최근1년
# 3    검암동           검암2차신명스카이뷰       1.0       84.97      400.0  최근1년
# 4    검암동           검암마젤란21아파트       1.0       84.59      540.0  최근1년
# ..   ...                  ...       ...         ...        ...   ...
# 451  NaN                  NaN       NaN         NaN        NaN   NaN
# 452  NaN                  NaN       NaN         NaN        NaN   NaN
# 453  NaN                  NaN       NaN         NaN        NaN   NaN
# 454  NaN                  NaN       NaN         NaN        NaN   NaN
# 455  NaN                  NaN       NaN         NaN        NaN   NaN
#
#            기준일자
# 0    2022-05-31
# 1    2022-05-31
# 2    2022-05-31
# 3    2022-05-31
# 4    2022-05-31
# ..          ...
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd

scores = np.random.randint(100, size=(3,4))
scores_df = pd.DataFrame(scores, index=['영어', '수학', '과학'], columns=['A', 'B', 'C', 'D'])
scores_df.to_excel('scores.xlsx')

# %%
df = pd.read_excel('/content/scores.xlsx')
df
# Out:
#   Unnamed: 0   A   B   C   D
# 0         영어  76  12  15  73
# 1         수학  77  59  12  61
# 2         과학  53  86  11  88

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/example.xlsx')
df
# Out:
#    Num  Name Grade
# 0    1   Kim    A+
# 1    2   Lee     A
# 2    3  Park     B
